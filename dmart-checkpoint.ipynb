# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import display

# %% [markdown]
# # collect dataset

# %%
dmartdata = pd.read_csv('dmart grocery sales.csv')
dmartdata
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %% [markdown]
# # check null value

# %%
dmartdata.isnull()
# Out:
#       Order ID  Customer Name  Category  Sub Category   City  Order Date  \
# 0        False          False     False         False  False       False
# 1        False          False     False         False  False       False
# 2        False          False     False         False  False       False
# 3        False          False     False         False  False       False
# 4        False          False     False         False  False       False
# ...        ...            ...       ...           ...    ...         ...
# 9989     False          False     False         False  False       False
# 9990     False          False     False         False  False       False
# 9991     False          False     False         False  False       False
# 9992     False          False     False         False  False       False
# 9993     False          False     False         False  False       False
#
#       Region  Sales  Discount  Profit  State
# 0      False  False     False   False  False
# ...

# %% [markdown]
# # sum of null values if present

# %%
dmartdata.isnull().sum()
# Out:
# Order ID         0
# Customer Name    0
# Category         0
# Sub Category     0
# City             0
# Order Date       0
# Region           0
# Sales            0
# Discount         0
# Profit           0
# State            0
# dtype: int64

# %% [markdown]
# # total no of rows and columns

# %%
dmartdata.shape
# Out:
# (9994, 11)

# %% [markdown]
# # overview

# %%
dmartdata.info
# Out:
# <bound method DataFrame.info of      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %% [markdown]
# # column names

# %%
dmartdata.columns
# Out:
# Index(['Order ID', 'Customer Name', 'Category', 'Sub Category', 'City',
#        'Order Date', 'Region', 'Sales', 'Discount', 'Profit', 'State'],
#       dtype='object')

# %% [markdown]
# # column data types

# %%
dmartdata.dtypes
# Out:
# Order ID          object
# Customer Name     object
# Category          object
# Sub Category      object
# City              object
# Order Date        object
# Region            object
# Sales              int64
# Discount         float64
# Profit           float64
# State             object
# dtype: object

# %% [markdown]
# # Basic statistics

# %%
dmartdata.describe()
# Out:
#              Sales     Discount       Profit
# count  9994.000000  9994.000000  9994.000000
# mean   1496.596158     0.226817   374.937082
# std     577.559036     0.074636   239.932881
# min     500.000000     0.100000    25.250000
# 25%    1000.000000     0.160000   180.022500
# 50%    1498.000000     0.230000   320.780000
# 75%    1994.750000     0.290000   525.627500
# max    2500.000000     0.350000  1120.950000

# %% [markdown]
# #  unique values in columns

# %%
dmartdata.value_counts('Category')
# Out:
# Category
# Snacks               1514
# Eggs, Meat & Fish    1490
# Fruits & Veggies     1418
# Bakery               1413
# Beverages            1400
# Food Grains          1398
# Oil & Masala         1361
# Name: count, dtype: int64

# %% [markdown]
# # obervation or accessing columns

# %%
dmartdata.iloc[:,[2,4,7]]
# Out:
#                Category         City  Sales
# 0          Oil & Masala      Vellore   1254
# 1             Beverages  Krishnagiri    749
# 2           Food Grains   Perambalur   2360
# 3      Fruits & Veggies   Dharmapuri    896
# 4           Food Grains         Ooty   2355
# ...                 ...          ...    ...
# 9989  Eggs, Meat & Fish      Madurai    945
# 9990             Bakery  Kanyakumari   1195
# 9991        Food Grains         Bodi   1567
# 9992       Oil & Masala   Pudukottai   1659
# 9993        Food Grains  Tirunelveli   1034
#
# [9994 rows x 3 columns]

# %% [markdown]
# # date format

# %%
dmartdata['Order Date'] = pd.to_datetime(dmartdata['Order Date'])

dmartdata['Order Date']
# Out:
# 0      2017-11-08
# 1      2017-11-08
# 2      2017-06-12
# 3      2016-10-11
# 4      2016-10-11
#           ...
# 9989   2015-12-24
# 9990   2015-07-12
# 9991   2017-06-06
# 9992   2018-10-16
# 9993   2018-04-17
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %% [markdown]
# # extract year from date format

# %%
dmartdata['Year'] = dmartdata['Order Date'].dt.year
dmartdata['Year']
# Out:
# 0       2017
# 1       2017
# 2       2017
# 3       2016
# 4       2016
#         ...
# 9989    2015
# 9990    2015
# 9991    2017
# 9992    2018
# 9993    2018
# Name: Year, Length: 9994, dtype: int32

# %% [markdown]
# # we need sum of sales values and sum of profit values for each unique category

# %%
grouped_data = dmartdata.groupby(['Category', ]).agg({
    'Sales': 'sum',
    'Profit': 'sum'
}).reset_index()
grouped_data
# Out:
#             Category    Sales     Profit
# 0             Bakery  2112281  528521.06
# 1          Beverages  2085313  525605.76
# 2  Eggs, Meat & Fish  2267401  567357.22
# 3        Food Grains  2115272  529162.64
# 4   Fruits & Veggies  2100727  530400.38
# 5       Oil & Masala  2038442  497895.29
# 6             Snacks  2237546  568178.85

# %% [markdown]
# # change data type of column

# %%
grouped_data['Profit'] = grouped_data['Profit'].astype(int)
grouped_data['Profit']
# Out:
# 0    528521
# 1    525605
# 2    567357
# 3    529162
# 4    530400
# 5    497895
# 6    568178
# Name: Profit, dtype: int64

# %%
grouped_data
# Out:
#             Category    Sales  Profit
# 0             Bakery  2112281  528521
# 1          Beverages  2085313  525605
# 2  Eggs, Meat & Fish  2267401  567357
# 3        Food Grains  2115272  529162
# 4   Fruits & Veggies  2100727  530400
# 5       Oil & Masala  2038442  497895
# 6             Snacks  2237546  568178

# %% [markdown]
# #

# %% [markdown]
# # BAR CHART

# %%
x = grouped_data['Category']
bar_width = 0.35 # a reasonable bar width
bar = np.arange(len(x))
bar1 = bar + bar_width # fix: Add a *fixed* offset

plt.figure(figsize=(11,6))
plt.bar(bar, grouped_data['Profit'], bar_width, label='Profit')
plt.bar(bar1, grouped_data['Sales'], bar_width, label='Sales')

plt.xticks(bar + bar_width/2, x) # fix: set x-ticks at center of bar groups
plt.ticklabel_format(axis='y', style='plain')

plt.legend(loc='upper left', fontsize=10)




#line graph
plt.plot(bar, grouped_data['Sales'], color='black', linestyle='--', marker='v', label='Sales Trend', linewidth=3)
plt.plot(bar, grouped_data['Profit'], color='black', linestyle='--', marker='v', label='Profit Trend', linewidth=3)


plt.title('Profit and sales per category', pad = 30, fontweight = 'bold', fontsize = 25)
plt.xticks( fontweight='bold')
plt.yticks(fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Percentage of particular value in any column is
# # (individual value /sum of all values ) * 100

# %% [markdown]
# # PIE CHART

# %%
plt.figure(figsize=(8, 8)) # Adjust figure size as needed
plt.pie(grouped_data['Sales'], 
        labels=grouped_data['Category'], 
        autopct='%1.1f%%', # Display percentage with 1 decimal place
        startangle=90,
        textprops={'fontsize': 15 },
      
        )     

 

    
plt.title("Sales Distribution by Category",fontsize=25, pad=40,loc='left',color = 'Chocolate', fontweight = 'bold')  # Add a title
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Frequency of cities in dataset

# %%
dmartdata['City'].value_counts()
# Out:
# City
# Kanyakumari       459
# Tirunelveli       446
# Bodi              442
# Krishnagiri       440
# Vellore           435
# Perambalur        434
# Tenkasi           432
# Chennai           432
# Salem             431
# Karur             430
# Pudukottai        430
# Coimbatore        428
# Ramanadhapuram    421
# Cumbum            417
# Virudhunagar      416
# Madurai           408
# Ooty              404
# Namakkal          403
# Viluppuram        397
# Dindigul          396
# Theni             387
# Dharmapuri        376
# Nagercoil         373
# Trichy            357
# Name: count, dtype: int64

# %% [markdown]
# # Categories per region

# %% [markdown]
# # CROSSTAB

# %%
pd.crosstab(dmartdata['Category'], dmartdata['Region'])
# Out:
# Region             Central  East  North  South  West
# Category
# Bakery                 309   392      0    240   472
# Beverages              343   385      0    227   445
# Eggs, Meat & Fish      331   449      0    233   477
# Food Grains            310   393      0    232   463
# Fruits & Veggies       355   384      0    234   445
# Oil & Masala           300   416      1    202   442
# Snacks                 375   429      0    251   459

# %%
pd.crosstab(dmartdata['City'], dmartdata['Profit'])
# Out:
# Profit          25.25    25.45    25.55    25.85    26.85    27.05    27.10    \
# City
# Bodi                  1        1        0        0        0        0        0
# Chennai               0        0        0        0        0        0        0
# Coimbatore            0        0        0        1        0        0        0
# Cumbum                0        0        0        0        0        0        0
# Dharmapuri            0        0        1        0        0        0        0
# Dindigul              0        0        0        0        0        0        0
# Kanyakumari           0        0        0        0        0        0        0
# Karur                 0        0        0        0        0        0        0
# Krishnagiri           0        0        0        0        0        0        0
# Madurai               0        0        0        0        0        0        0
# Nagercoil             0        0        0        0        0        0        0
# ...

# %% [markdown]
# # Total sales and profit of each city

# %%
cityprofit1 = dmartdata.groupby(['City' ]).agg({
    'Sales': 'sum',
    'Profit': 'sum'
}).reset_index()
cityprofit1
# Out:
#               City   Sales     Profit
# 0             Bodi  667177  173655.13
# 1          Chennai  634963  160921.33
# 2       Coimbatore  634748  157399.41
# 3           Cumbum  626047  156355.13
# 4       Dharmapuri  571553  141593.05
# 5         Dindigul  575631  144872.95
# 6      Kanyakumari  706764  172217.74
# 7            Karur  642273  169305.94
# 8      Krishnagiri  637273  160477.48
# 9          Madurai  617836  152548.61
# 10       Nagercoil  551435  137848.47
# 11        Namakkal  598530  145502.10
# 12            Ooty  599292  150078.92
# 13      Perambalur  659738  171132.19
# 14      Pudukottai  653179  164072.63
# 15  Ramanadhapuram  634386  158951.03
# 16           Salem  657093  160899.30
# 17         Tenkasi  643652  156230.72
# 18           Theni  579553  142739.78
# 19     Tirunelveli  659812  165169.01
# 20          Trichy  541403  136059.94
# 21         Vellore  676550  174073.01
# 22      Viluppuram  581274  144200.64
# 23    Virudhunagar  606820  150816.69

# %%
cityprofit = dmartdata.groupby(['City' ]).agg({
    'Sales': 'sum',
    
}).reset_index()
cityprofit
# Out:
#               City   Sales
# 0             Bodi  667177
# 1          Chennai  634963
# 2       Coimbatore  634748
# 3           Cumbum  626047
# 4       Dharmapuri  571553
# 5         Dindigul  575631
# 6      Kanyakumari  706764
# 7            Karur  642273
# 8      Krishnagiri  637273
# 9          Madurai  617836
# 10       Nagercoil  551435
# 11        Namakkal  598530
# 12            Ooty  599292
# 13      Perambalur  659738
# 14      Pudukottai  653179
# 15  Ramanadhapuram  634386
# 16           Salem  657093
# 17         Tenkasi  643652
# 18           Theni  579553
# 19     Tirunelveli  659812
# 20          Trichy  541403
# 21         Vellore  676550
# 22      Viluppuram  581274
# 23    Virudhunagar  606820

# %%
plt.figure(figsize=(15, 6))
sns.barplot(x=cityprofit['City'], y=cityprofit['Sales'],palette='viridis')
plt.title('Total Sales by City', fontsize=25,fontweight= 'bold',pad = 20)
plt.xlabel('City', fontsize=19,fontweight = 'bold')
plt.ylabel('Total Sales', fontsize=19,fontweight = 'bold')
plt.xticks(rotation=90,fontsize = 16)
plt.yticks(fontsize = 16)
plt.show()
# Out:
# C:\Users\Intel\AppData\Local\Temp\ipykernel_8392\1366954205.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cityprofit['City'], y=cityprofit['Sales'],palette='viridis')

# %% [markdown]
# # City with maximum sales

# %%
cityprofit1.loc[cityprofit1['Sales'].idxmax()]
# Out:
# City      Kanyakumari
# Sales          706764
# Profit      172217.74
# Name: 6, dtype: object

# %% [markdown]
# # City with maximum profits

# %%
cityprofit1.loc[cityprofit1['Profit'].idxmax()]
# Out:
# City        Vellore
# Sales        676550
# Profit    174073.01
# Name: 21, dtype: object

# %% [markdown]
# # City with minimum sales

# %%
cityprofit1.loc[cityprofit1['Sales'].idxmin()]
# Out:
# City         Trichy
# Sales        541403
# Profit    136059.94
# Name: 20, dtype: object

# %% [markdown]
# # City with minimum profit

# %%
cityprofit1.loc[cityprofit1['Profit'].idxmin()]
# Out:
# City         Trichy
# Sales        541403
# Profit    136059.94
# Name: 20, dtype: object

# %% [markdown]
# #  sales per month

# %%
dmartdata['Year'] = dmartdata['Order Date'].dt.year

dmartdata['Month'] = dmartdata['Order Date'].dt.month
monthly_sales = dmartdata.groupby(['Year', 'Month'])['Sales'].sum()
monthly_sales
# Out:
# Year  Month
# 2015  1        122497
#       2         66030
#       3        247156
#       4        203258
#       5        164263
#       6        206064
#       7        220986
#       8        230161
#       9        382200
#       10       241726
#       11       480979
#       12       410279
# 2016  1         89009
#       2         90823
#       3        212164
#       4        237272
#       5        222722
#       6        205388
#       7        215776
#       8        229543
#       9        429658
#       10       249639
#       11       477720
#       12       472245
# 2017  1        131727
#       2        132982
#       3        238956
#       4        247773
#       5        332524
#       6        291454
#       7        315531
#       8        256089
#       9        546728
#       10       308026
#       11       551815
#       12       518307
# 2018  1        234739
#       2        166267
#       3        355704
#       4        310150
#       5        367411
# ...

# %% [markdown]
# # Total sales per month

# %%
monthly_sales = dmartdata.groupby([ 'Month'])['Sales'].sum()
monthly_sales
# Out:
# Month
# 1      577972
# 2      456102
# 3     1053980
# 4      998453
# 5     1086920
# 6     1057808
# 7     1089385
# 8     1046807
# 9     2064266
# 10    1243289
# 11    2193924
# 12    2088076
# Name: Sales, dtype: int64

# %% [markdown]
# # Total sales per year

# %%
dmartdata['Year'] = dmartdata['Order Date'].dt.year


monthly_sales = dmartdata.groupby('Year')['Sales'].sum()
monthly_sales
# Out:
# Year
# 2015    2975599
# 2016    3131959
# 2017    3871912
# 2018    4977512
# Name: Sales, dtype: int64

# %% [markdown]
# # Line plot

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_sales, marker='o')
plt.title('Sales Trend Over Time', fontsize=25,fontweight='bold',pad = 20)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Total Sales', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # maximum sales per year

# %%
monthly_sales = dmartdata.groupby('Year')['Sales'].max()
monthly_sales
# Out:
# Year
# 2015    2500
# 2016    2500
# 2017    2500
# 2018    2500
# Name: Sales, dtype: int64

# %%
citysub = dmartdata.groupby('Sub Category')['City'].value_counts()
citysub
# Out:
# Sub Category  City
# Atta & Flour  Viluppuram      22
#               Virudhunagar    21
#               Karur           20
#               Coimbatore      18
#               Pudukottai      17
#                               ..
# Spices        Dharmapuri      15
#               Madurai         15
#               Coimbatore      14
#               Dindigul        14
#               Trichy          14
# Name: count, Length: 552, dtype: int64

# %%
dmartdata.iloc[:,[3,4,7]]
# Out:
#           Sub Category         City  Sales
# 0              Masalas      Vellore   1254
# 1        Health Drinks  Krishnagiri    749
# 2         Atta & Flour   Perambalur   2360
# 3     Fresh Vegetables   Dharmapuri    896
# 4      Organic Staples         Ooty   2355
# ...                ...          ...    ...
# 9989              Eggs      Madurai    945
# 9990          Biscuits  Kanyakumari   1195
# 9991              Rice         Bodi   1567
# 9992            Spices   Pudukottai   1659
# 9993      Atta & Flour  Tirunelveli   1034
#
# [9994 rows x 3 columns]

# %% [markdown]
# # Sales distribution per sub category

# %%
cat1 =dmartdata.groupby('Sub Category')['Sales'].sum()
cat1 =pd.DataFrame(cat1)
cat1
# Out:
#                       Sales
# Sub Category
# Atta & Flour         534649
# Biscuits             684083
# Breads & Buns        742586
# Cakes                685612
# Chicken              520497
# Chocolates           733898
# Cookies              768213
# Dals & Pulses        523371
# Edible Oil & Ghee    668086
# Eggs                 575156
# Fish                 560548
# Fresh Fruits         551212
# Fresh Vegetables     525842
# Health Drinks       1051439
# Masalas              697480
# Mutton               611200
# Noodles              735435
# Organic Fruits       503402
# Organic Staples      558929
# Organic Vegetables   520271
# Rice                 498323
# Soft Drinks         1033874
# Spices               672876

# %%
cat1
# Out:
#                       Sales
# Sub Category
# Atta & Flour         534649
# Biscuits             684083
# Breads & Buns        742586
# Cakes                685612
# Chicken              520497
# Chocolates           733898
# Cookies              768213
# Dals & Pulses        523371
# Edible Oil & Ghee    668086
# Eggs                 575156
# Fish                 560548
# Fresh Fruits         551212
# Fresh Vegetables     525842
# Health Drinks       1051439
# Masalas              697480
# Mutton               611200
# Noodles              735435
# Organic Fruits       503402
# Organic Staples      558929
# Organic Vegetables   520271
# Rice                 498323
# Soft Drinks         1033874
# Spices               672876

# %%
cat1['Sales']
# Out:
# Sub Category
# Atta & Flour           534649
# Biscuits               684083
# Breads & Buns          742586
# Cakes                  685612
# Chicken                520497
# Chocolates             733898
# Cookies                768213
# Dals & Pulses          523371
# Edible Oil & Ghee      668086
# Eggs                   575156
# Fish                   560548
# Fresh Fruits           551212
# Fresh Vegetables       525842
# Health Drinks         1051439
# Masalas                697480
# Mutton                 611200
# Noodles                735435
# Organic Fruits         503402
# Organic Staples        558929
# Organic Vegetables     520271
# Rice                   498323
# Soft Drinks           1033874
# Spices                 672876
# Name: Sales, dtype: int64

# %%
cat = cat1.iloc[:]
cat
# Out:
#                       Sales
# Sub Category
# Atta & Flour         534649
# Biscuits             684083
# Breads & Buns        742586
# Cakes                685612
# Chicken              520497
# Chocolates           733898
# Cookies              768213
# Dals & Pulses        523371
# Edible Oil & Ghee    668086
# Eggs                 575156
# Fish                 560548
# Fresh Fruits         551212
# Fresh Vegetables     525842
# Health Drinks       1051439
# Masalas              697480
# Mutton               611200
# Noodles              735435
# Organic Fruits       503402
# Organic Staples      558929
# Organic Vegetables   520271
# Rice                 498323
# Soft Drinks         1033874
# Spices               672876

# %%
cat['Sales']
# Out:
# Sub Category
# Atta & Flour           534649
# Biscuits               684083
# Breads & Buns          742586
# Cakes                  685612
# Chicken                520497
# Chocolates             733898
# Cookies                768213
# Dals & Pulses          523371
# Edible Oil & Ghee      668086
# Eggs                   575156
# Fish                   560548
# Fresh Fruits           551212
# Fresh Vegetables       525842
# Health Drinks         1051439
# Masalas                697480
# Mutton                 611200
# Noodles                735435
# Organic Fruits         503402
# Organic Staples        558929
# Organic Vegetables     520271
# Rice                   498323
# Soft Drinks           1033874
# Spices                 672876
# Name: Sales, dtype: int64

# %%
catty=cat1.reset_index()
catty
# Out:
#           Sub Category    Sales
# 0         Atta & Flour   534649
# 1             Biscuits   684083
# 2        Breads & Buns   742586
# 3                Cakes   685612
# 4              Chicken   520497
# 5           Chocolates   733898
# 6              Cookies   768213
# 7        Dals & Pulses   523371
# 8    Edible Oil & Ghee   668086
# 9                 Eggs   575156
# 10                Fish   560548
# 11        Fresh Fruits   551212
# 12    Fresh Vegetables   525842
# 13       Health Drinks  1051439
# 14             Masalas   697480
# 15              Mutton   611200
# 16             Noodles   735435
# 17      Organic Fruits   503402
# 18     Organic Staples   558929
# 19  Organic Vegetables   520271
# 20                Rice   498323
# 21         Soft Drinks  1033874
# 22              Spices   672876

# %%
catty['Sales']
# Out:
# 0      534649
# 1      684083
# 2      742586
# 3      685612
# 4      520497
# 5      733898
# 6      768213
# 7      523371
# 8      668086
# 9      575156
# 10     560548
# 11     551212
# 12     525842
# 13    1051439
# 14     697480
# 15     611200
# 16     735435
# 17     503402
# 18     558929
# 19     520271
# 20     498323
# 21    1033874
# 22     672876
# Name: Sales, dtype: int64

# %% [markdown]
# # Converting columns to list

# %%
x = catty ['Sub Category'].tolist()
y = catty['Sales'].tolist()
x
# Out:
# ['Atta & Flour',
#  'Biscuits',
#  'Breads & Buns',
#  'Cakes',
#  'Chicken',
#  'Chocolates',
#  'Cookies',
#  'Dals & Pulses',
#  'Edible Oil & Ghee',
#  'Eggs',
#  'Fish',
#  'Fresh Fruits',
#  'Fresh Vegetables',
#  'Health Drinks',
#  'Masalas',
#  'Mutton',
#  'Noodles',
#  'Organic Fruits',
#  'Organic Staples',
#  'Organic Vegetables',
#  'Rice',
#  'Soft Drinks',
#  'Spices']

# %%
y
# Out:
# [534649,
#  684083,
#  742586,
#  685612,
#  520497,
#  733898,
#  768213,
#  523371,
#  668086,
#  575156,
#  560548,
#  551212,
#  525842,
#  1051439,
#  697480,
#  611200,
#  735435,
#  503402,
#  558929,
#  520271,
#  498323,
#  1033874,
#  672876]

# %%
# Bar chart

# %%
plt.figure(figsize=(19,16))
plt.barh(x,y)
for index, value in enumerate(y):
    plt.text(value + 20000, index, str(value), va='center', fontsize=14, fontweight='bold', color='darkblue')
plt.xlim(0, max(y) * 1.1)
plt.xticks(rotation = 90)
plt.yticks(fontweight = 'bold',fontsize = 18)
plt.xticks(fontsize = 18)
plt.xlabel('Sales',fontweight = 'bold',fontsize = 20)
plt.title('Sales per subcategory',fontweight = 'bold',fontsize = 30, pad = 30, color ='chocolate')
plt.show()

# %%
min(y)
# Out:
# 498323

# %%
max(y)
# Out:
# 1051439
